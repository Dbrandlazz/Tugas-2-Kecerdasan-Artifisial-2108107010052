# %% [markdown]
# # Intel Image Classification (CNN - Keras)
#
# Hello, I hope you are having a great day.
#
# In this notebook, I will try the process of implementing CNN with Keras in order to classify images.
# 1. Firstly, we'll import usefull packages.
# 1. Then, we'll load the data, before visualize and preprocess it.
# 1. We'll try a simple CNN model and then we will evaluate its performances.
# 1. We will then use pre trained model to address this challenge aswell.

# %% [markdown]
# # Import Packages

# %%
import numpy as np
import os
from sklearn.metrics import confusion_matrix
import seaborn as sn; sn.set(font_scale=1.4)
from sklearn.utils import shuffle           
import matplotlib.pyplot as plt             
import cv2
import datetime
import tensorflow as tf                
from tqdm import tqdm
from tensorflow.keras.callbacks import TensorBoard
from tensorflow.keras.callbacks import EarlyStopping
from keras.preprocessing.image import ImageDataGenerator

# %%
# Create a TensorBoard callback
log_dir = "logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")  # Adjust the log directory as needed
tensorboard_callback = TensorBoard(log_dir=log_dir, histogram_freq=1)

# %%
class_names = ['mountain', 'buildings', 'sea']
class_names_label = {class_name:i for i, class_name in enumerate(class_names)}

nb_classes = len(class_names)

IMAGE_SIZE = (150, 150)

# %% [markdown]
# # Loading the Data
# We have to write a load_data function that load the images and the labels from the folder.

# %%
def load_data():
    """
        Load the data:
            - 14,034 images to train the network.
            - 3,000 images to evaluate how accurately the network learned to classify images.
    """
    
    datasets = ['../seg_train/seg_train', '../seg_test/seg_test']
    output = []
    
    # Iterate through training and test sets
    for dataset in datasets:
        
        images = []
        labels = []
        
        print("Loading {}".format(dataset))
        
        # Iterate through each folder corresponding to a category
        for folder in os.listdir(dataset):
            label = class_names_label[folder]
            
            # Iterate through each image in our folder
            for file in tqdm(os.listdir(os.path.join(dataset, folder))):
                
                # Get the path name of the image
                img_path = os.path.join(os.path.join(dataset, folder), file)
                
                # Open and resize the img
                image = cv2.imread(img_path)
                image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
                image = cv2.resize(image, IMAGE_SIZE) 
                
                # Append the image and its corresponding label to the output
                images.append(image)
                labels.append(label)
                
        images = np.array(images, dtype = 'float32')
        labels = np.array(labels, dtype = 'int32')   
        
        output.append((images, labels))

    return output

# %%
(train_images, train_labels), (test_images, test_labels) = load_data()
# Out:
# Loading ../seg_train/seg_train
# 100%|██████████| 619/619 [00:00<00:00, 846.33it/s]
# 100%|██████████| 476/476 [00:00<00:00, 1073.58it/s]
# 100%|██████████| 777/777 [00:00<00:00, 1085.43it/s]
# Loading ../seg_test/seg_test
# 100%|██████████| 212/212 [00:00<00:00, 792.86it/s]
# 100%|██████████| 192/192 [00:00<00:00, 1048.20it/s]
# 100%|██████████| 216/216 [00:00<00:00, 1036.41it/s]

# %%
train_images, train_labels = shuffle(train_images, train_labels, random_state=25)

# %% [markdown]
# # Let's explore the dataset
# We can ask ourselves:
# * How many training and testing examples do we have ?
# * What is the size of the images ?
# * What is the proportion of each observed category ?

# %%
n_train = train_labels.shape[0]
n_test = test_labels.shape[0]

print ("Number of training examples: {}".format(n_train))
print ("Number of testing examples: {}".format(n_test))
print ("Each image is of size: {}".format(IMAGE_SIZE))
# Out:
# Number of training examples: 1872
# Number of testing examples: 620
# Each image is of size: (150, 150)

# %%
import pandas as pd

_, train_counts = np.unique(train_labels, return_counts=True)
_, test_counts = np.unique(test_labels, return_counts=True)
pd.DataFrame({'train': train_counts,
                    'test': test_counts}, 
             index=class_names
            ).plot.bar()
plt.show()

# %%
import matplotlib.pyplot as plt

# Assuming train_counts is a list or array containing numerical values for each category
train_counts = [10, 20, 30]  # Replace this with your actual data
explode = (0, 0, 0)  # Adjust the explode values as needed
labels = class_names  # Assuming class_names is a list containing the category names

plt.pie(train_counts, explode=explode, labels=labels, autopct='%1.1f%%')
plt.axis('equal')
plt.title('Proportion of each observed category')
plt.show()

# %% [markdown]
# ## Good practice: scale the data

# %%
train_images = train_images / 255.0 
test_images = test_images / 255.0

# %% [markdown]
# ## Visualize the data
# We can display a random image from the training set.

# %%
def display_random_image(class_names, images, labels):
    """
        Display a random image from the images array and its correspond label from the labels array.
    """
    
    index = np.random.randint(images.shape[0])
    plt.figure()
    plt.imshow(images[index])
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.title('Image #{} : '.format(index) + class_names[labels[index]])
    plt.show()

# %%
display_random_image(class_names, train_images, train_labels)

# %% [markdown]
# We can also display the first 25 images from the training set directly with a loop to get a better view

# %%
def display_examples(class_names, images, labels):
    """
        Display 25 images from the images array with its corresponding labels
    """
    
    fig = plt.figure(figsize=(10,10))
    fig.suptitle("Some examples of images of the dataset", fontsize=16)
    for i in range(25):
        plt.subplot(5,5,i+1)
        plt.xticks([])
        plt.yticks([])
        plt.grid(False)
        plt.imshow(images[i], cmap=plt.cm.binary)
        plt.xlabel(class_names[labels[i]])
    plt.show()

# %%
display_examples(class_names, train_images, train_labels)

# %% [markdown]
# # Beginner: Simple Model Creation
#
# Steps are:
# 1. Build the model,
# 1. Compile the model,
# 1. Train / fit the data to the model,
# 1. Evaluate the model on the testing set,
# 1. Carry out an error analysis of our model.
#
# We can build an easy model composed of different layers such as:
# * Conv2D: (32 filters of size 3 by 3) The features will be "extracted" from the image.
# * MaxPooling2D: The images get half sized.
# * Flatten: Transforms the format of the images from a 2d-array to a 1d-array of 150 150 3 pixel values.
# * Relu  : given a value x, returns max(x, 0).
# * Softmax: 6 neurons, probability that the image belongs to one of the classes.

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Conv2D(32, (3, 3), activation = 'relu', input_shape = (150, 150, 3)), 
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(32, (3, 3), activation = 'relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(112, activation=tf.nn.relu),
    tf.keras.layers.Dense(6, activation=tf.nn.softmax)
])
# Out:
# WARNING:tensorflow:From c:\Users\MARLINA\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From c:\Users\MARLINA\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\pooling\max_pooling2d.py:161: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.

# %% [markdown]
# Then, we can compile it with some parameters such as:
# * **Optimizer**: adam = RMSProp + Momentum.
# What is Momentum and RMSProp ?
# * Momentum = takes into account past gradient to have a better update.
# * RMSProp = exponentially weighted average of the squares of past gradients.
# * **Loss function**: we use sparse categorical crossentropy for classification, each images belongs to one class only

# %%
model.compile(optimizer = 'adam', loss = 'sparse_categorical_crossentropy', metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From c:\Users\MARLINA\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
history = model.fit(train_images, train_labels, batch_size=128, epochs=15, validation_split = 0.2)
# Out:
# Epoch 1/15
# WARNING:tensorflow:From c:\Users\MARLINA\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From c:\Users\MARLINA\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 12/12 [==============================] - 22s 2s/step - loss: 1.5079 - accuracy: 0.4255 - val_loss: 0.9980 - val_accuracy: 0.5253
# Epoch 2/15
# 12/12 [==============================] - 16s 1s/step - loss: 0.9204 - accuracy: 0.6019 - val_loss: 0.8990 - val_accuracy: 0.6507
# Epoch 3/15
# 12/12 [==============================] - 15s 1s/step - loss: 0.8366 - accuracy: 0.6553 - val_loss: 0.8080 - val_accuracy: 0.6533
# Epoch 4/15
# 12/12 [==============================] - 14s 1s/step - loss: 0.6859 - accuracy: 0.7121 - val_loss: 0.6816 - val_accuracy: 0.7200
# Epoch 5/15
# 12/12 [==============================] - 14s 1s/step - loss: 0.5662 - accuracy: 0.7902 - val_loss: 0.6542 - val_accuracy: 0.7200
# Epoch 6/15
# 12/12 [==============================] - 14s 1s/step - loss: 0.4795 - accuracy: 0.8110 - val_loss: 0.6320 - val_accuracy: 0.7333
# Epoch 7/15
# 12/12 [==============================] - 14s 1s/step - loss: 0.4105 - accuracy: 0.8397 - val_loss: 0.5704 - val_accuracy: 0.7840
# Epoch 8/15
# 12/12 [==============================] - 14s 1s/step - loss: 0.3289 - accuracy: 0.8864 - val_loss: 0.5262 - val_accuracy: 0.8000
# Epoch 9/15
# 12/12 [==============================] - 14s 1s/step - loss: 0.3027 - accuracy: 0.8898 - val_loss: 0.5953 - val_accuracy: 0.7440
# Epoch 10/15
# 12/12 [==============================] - 15s 1s/step - loss: 0.2662 - accuracy: 0.9118 - val_loss: 0.5688 - val_accuracy: 0.7627
# Epoch 11/15
# 12/12 [==============================] - 13s 1s/step - loss: 0.2127 - accuracy: 0.9352 - val_loss: 0.6006 - val_accuracy: 0.8027
# Epoch 12/15
# 12/12 [==============================] - 14s 1s/step - loss: 0.1834 - accuracy: 0.9512 - val_loss: 0.6256 - val_accuracy: 0.7467
# Epoch 13/15
# 12/12 [==============================] - 14s 1s/step - loss: 0.1764 - accuracy: 0.9452 - val_loss: 0.6030 - val_accuracy: 0.7973
# Epoch 14/15
# 12/12 [==============================] - 13s 1s/step - loss: 0.1413 - accuracy: 0.9559 - val_loss: 0.5783 - val_accuracy: 0.8000
# Epoch 15/15
# 12/12 [==============================] - 13s 1s/step - loss: 0.1056 - accuracy: 0.9786 - val_loss: 0.6471 - val_accuracy: 0.7813

# %% [markdown]
# We fit the model to the data from the training set. The neural network will learn by itself the pattern in order to distinguish each category.

# %%
def plot_accuracy_loss(history):
    """
    Plot the accuracy and the loss during the training of the nn.
    """
    fig = plt.figure(figsize=(10, 5))

    # Plot accuracy
    plt.subplot(221)
    plt.plot(history.history['accuracy'], 'bo--', label="accuracy")
    plt.plot(history.history['val_accuracy'], 'ro--', label="val_accuracy")
    plt.title("train_accuracy vs val_accuracy")
    plt.ylabel("accuracy")
    plt.xlabel("epochs")
    plt.legend()

    # Plot loss function
    plt.subplot(222)
    plt.plot(history.history['loss'], 'bo--', label="loss")
    plt.plot(history.history['val_loss'], 'ro--', label="val_loss")
    plt.title("train_loss vs val_loss")
    plt.ylabel("loss")
    plt.xlabel("epochs")

    plt.legend()
    plt.show()

# %%
plot_accuracy_loss(history)

# %% [markdown]
# We should evaluate the model performance on test set

# %%
test_loss = model.evaluate(test_images, test_labels)
# Out:
# 20/20 [==============================] - 2s 71ms/step - loss: 0.7052 - accuracy: 0.7694

# %% [markdown]
# We see that we achieve 0.76 accuracy on the testing test. We got a slight underfitting :(
#
# Let's see how the classifier is doing on random images.

# %%
predictions = model.predict(test_images)     # Vector of probabilities
pred_labels = np.argmax(predictions, axis = 1) # We take the highest probability

display_random_image(class_names, test_images, pred_labels)
# Out:
# 20/20 [==============================] - 2s 73ms/step

# %% [markdown]
# ## Error analysis
#
# We can try to understand on which kind of images the classifier has trouble.

# %%
def print_mislabeled_images(class_names, test_images, test_labels, pred_labels):
    """
        Print 25 examples of mislabeled images by the classifier, e.g when test_labels != pred_labels
    """
    BOO = (test_labels == pred_labels)
    mislabeled_indices = np.where(BOO == 0)
    mislabeled_images = test_images[mislabeled_indices]
    mislabeled_labels = pred_labels[mislabeled_indices]

    title = "Some examples of mislabeled images by the classifier:"
    display_examples(class_names,  mislabeled_images, mislabeled_labels)

# %%
print_mislabeled_images(class_names, test_images, test_labels, pred_labels)

# %%
CM = confusion_matrix(test_labels, pred_labels)
ax = plt.axes()
sn.heatmap(CM, annot=True, 
           annot_kws={"size": 10}, 
           xticklabels=class_names, 
           yticklabels=class_names, ax = ax)
ax.set_title('Confusion matrix')
plt.show()

# %% [markdown]
# ## Conclusion: The classifier has trouble with 2 kinds of images.
# It has trouble with street and buildings. Well, it can be understandable as as there are buildings in the street.
# It has also trouble with sea, glacier and moutain as well. It is hard for me to fully distinguish them.
# However, it can detects forest very accurately!

# %% [markdown]
# **Intermediate Update January 2020**
#
# * Feature extraction with VGG16 trained on ImageNet
#
#
# * Ensemble models of Neural Networks with the features extracted from VGG
#
# Inspired from: https://machinelearningmastery.com/model-averaging-ensemble-for-deep-learning-neural-networks/
#
# * Fine Tuning with VGG16 trained on ImageNet

# %% [markdown]
# # Feature extraction with VGG ImageNet

# %% [markdown]
# We can extract features from VGG16.

# %%
from keras.applications.vgg16 import VGG16
from keras.preprocessing import image
from keras.applications.vgg16 import preprocess_input

model = VGG16(weights='imagenet', include_top=False)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 24s 0us/step

# %% [markdown]
# Get the features directly from VGG16

# %%
train_features = model.predict(train_images)
test_features = model.predict(test_images)
# Out:
# 59/59 [==============================] - 63s 1s/step
# 20/20 [==============================] - 18s 888ms/step

# %% [markdown]
# ## Visualize the features through PCA

# %%
n_train, x, y, z = train_features.shape
n_test, x, y, z = test_features.shape
numFeatures = x * y * z

# %%
from sklearn import decomposition

pca = decomposition.PCA(n_components = 2)

X = train_features.reshape((n_train, x*y*z))
pca.fit(X)

C = pca.transform(X) # Représentation des individus dans les nouveaux axe
C1 = C[:,0]
C2 = C[:,1]

# %%
### Figures

plt.subplots(figsize=(10,10))

for i, class_name in enumerate(class_names):
    plt.scatter(C1[train_labels == i][:1000], C2[train_labels == i][:1000], label = class_name, alpha=0.4)
plt.legend()
plt.title("PCA Projection")
plt.show()

# %% [markdown]
# We can identifying clusters thanks to this PCA. The clusters correspond more or less to the labels.
#
# We see that glacier and mountain points are very close to each other, as VGG sees them as very similar.
#
# We see that there is no distinction between building and street.

# %% [markdown]
# ## Training on top of VGG
#
# Let's train a simple one-layer Neural Network on the features extracted from VGG.

# %%
model2 = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape = (x, y, z)),
    tf.keras.layers.Dense(50, activation=tf.nn.relu),
    tf.keras.layers.Dense(6, activation=tf.nn.softmax)
])

model2.compile(optimizer = 'adam', loss = 'sparse_categorical_crossentropy', metrics=['accuracy'])

history2 = model2.fit(train_features, train_labels, batch_size=112, epochs=15, validation_split = 0.2)
# Out:
# Epoch 1/15
# 14/14 [==============================] - 1s 39ms/step - loss: 0.5945 - accuracy: 0.7355 - val_loss: 0.2780 - val_accuracy: 0.8827
# Epoch 2/15
# 14/14 [==============================] - 0s 24ms/step - loss: 0.2122 - accuracy: 0.9172 - val_loss: 0.2268 - val_accuracy: 0.9093
# Epoch 3/15
# 14/14 [==============================] - 0s 21ms/step - loss: 0.1462 - accuracy: 0.9459 - val_loss: 0.2176 - val_accuracy: 0.9067
# Epoch 4/15
# 14/14 [==============================] - 0s 19ms/step - loss: 0.1125 - accuracy: 0.9599 - val_loss: 0.1851 - val_accuracy: 0.9227
# Epoch 5/15
# 14/14 [==============================] - 0s 19ms/step - loss: 0.0872 - accuracy: 0.9699 - val_loss: 0.1835 - val_accuracy: 0.9280
# Epoch 6/15
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0705 - accuracy: 0.9780 - val_loss: 0.1797 - val_accuracy: 0.9253
# Epoch 7/15
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0574 - accuracy: 0.9846 - val_loss: 0.1863 - val_accuracy: 0.9333
# Epoch 8/15
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0517 - accuracy: 0.9886 - val_loss: 0.1650 - val_accuracy: 0.9280
# Epoch 9/15
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0434 - accuracy: 0.9913 - val_loss: 0.1748 - val_accuracy: 0.9387
# Epoch 10/15
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0360 - accuracy: 0.9953 - val_loss: 0.1748 - val_accuracy: 0.9360
# Epoch 11/15
# 14/14 [==============================] - 0s 18ms/step - loss: 0.0345 - accuracy: 0.9953 - val_loss: 0.1625 - val_accuracy: 0.9307
# Epoch 12/15
# 14/14 [==============================] - 0s 20ms/step - loss: 0.0278 - accuracy: 0.9987 - val_loss: 0.1656 - val_accuracy: 0.9333
# Epoch 13/15
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0246 - accuracy: 0.9987 - val_loss: 0.1726 - val_accuracy: 0.9333
# Epoch 14/15
# 14/14 [==============================] - 0s 21ms/step - loss: 0.0227 - accuracy: 0.9987 - val_loss: 0.1652 - val_accuracy: 0.9387
# Epoch 15/15
# 14/14 [==============================] - 0s 23ms/step - loss: 0.0193 - accuracy: 0.9980 - val_loss: 0.1698 - val_accuracy: 0.9280

# %%
plot_accuracy_loss(history)

# %% [markdown]
# We should get approximately 0.844 accuracy (+0.1 accuracy) over the simple ConvNet.

# %%
test_loss = model2.evaluate(test_features, test_labels)
# Out:
# 20/20 [==============================] - 0s 3ms/step - loss: 0.1556 - accuracy: 0.9452

# %% [markdown]
# # Ensemble Neural Networks

# %%
np.random.seed(seed=1997)
# Number of estimators
n_estimators = 10
# Proporition of samples to use to train each training
max_samples = 0.8

max_samples *= n_train
max_samples = int(max_samples)

# %% [markdown]
# We define n_estimators Neural Networks.
#
# Each Neural Network will be trained on random subsets of the training dataset. Each subset contains max_samples samples.

# %%
models = list()
random = np.random.randint(50, 100, size = n_estimators)

for i in range(n_estimators):
    
    # Model
    model = tf.keras.Sequential([ tf.keras.layers.Flatten(input_shape = (x, y, z)),
                                # One layer with random size
                                    tf.keras.layers.Dense(random[i], activation=tf.nn.relu),
                                    tf.keras.layers.Dense(6, activation=tf.nn.softmax)
                                ])
    
    model.compile(optimizer = 'adam', loss = 'sparse_categorical_crossentropy', metrics=['accuracy'])
    
    # Store model
    models.append(model)

# %%
histories = []

for i in range(n_estimators):
    # Train each model on a bag of the training data
    train_idx = np.random.choice(len(train_features), size = max_samples)
    histories.append(models[i].fit(train_features[train_idx], train_labels[train_idx], batch_size=128, epochs=10, validation_split = 0.1))
# Out:
# Epoch 1/10
# 11/11 [==============================] - 1s 42ms/step - loss: 0.4884 - accuracy: 0.8144 - val_loss: 0.1820 - val_accuracy: 0.9333
# Epoch 2/10
# 11/11 [==============================] - 0s 31ms/step - loss: 0.1474 - accuracy: 0.9443 - val_loss: 0.1310 - val_accuracy: 0.9533
# Epoch 3/10
# 11/11 [==============================] - 0s 38ms/step - loss: 0.0859 - accuracy: 0.9755 - val_loss: 0.1060 - val_accuracy: 0.9600
# Epoch 4/10
# 11/11 [==============================] - 0s 36ms/step - loss: 0.0561 - accuracy: 0.9881 - val_loss: 0.0794 - val_accuracy: 0.9867
# Epoch 5/10
# 11/11 [==============================] - 0s 24ms/step - loss: 0.0382 - accuracy: 0.9918 - val_loss: 0.0865 - val_accuracy: 0.9800
# Epoch 6/10
# 11/11 [==============================] - 0s 25ms/step - loss: 0.0282 - accuracy: 0.9955 - val_loss: 0.0788 - val_accuracy: 0.9800
# Epoch 7/10
# 11/11 [==============================] - 0s 25ms/step - loss: 0.0208 - accuracy: 0.9985 - val_loss: 0.0741 - val_accuracy: 0.9733
# Epoch 8/10
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0197 - accuracy: 0.9993 - val_loss: 0.0767 - val_accuracy: 0.9800
# Epoch 9/10
# 11/11 [==============================] - 0s 23ms/step - loss: 0.0141 - accuracy: 0.9993 - val_loss: 0.0793 - val_accuracy: 0.9733
# Epoch 10/10
# 11/11 [==============================] - 0s 23ms/step - loss: 0.0130 - accuracy: 0.9993 - val_loss: 0.0916 - val_accuracy: 0.9667
# Epoch 1/10
# 11/11 [==============================] - 1s 48ms/step - loss: 0.6751 - accuracy: 0.7498 - val_loss: 0.2527 - val_accuracy: 0.8733
# Epoch 2/10
# 11/11 [==============================] - 0s 31ms/step - loss: 0.2149 - accuracy: 0.9183 - val_loss: 0.1487 - val_accuracy: 0.9400
# Epoch 3/10
# 11/11 [==============================] - 0s 35ms/step - loss: 0.1459 - accuracy: 0.9458 - val_loss: 0.1171 - val_accuracy: 0.9400
# Epoch 4/10
# 11/11 [==============================] - 0s 43ms/step - loss: 0.1032 - accuracy: 0.9666 - val_loss: 0.1081 - val_accuracy: 0.9533
# Epoch 5/10
# 11/11 [==============================] - 0s 40ms/step - loss: 0.0853 - accuracy: 0.9762 - val_loss: 0.1261 - val_accuracy: 0.9400
# Epoch 6/10
# 11/11 [==============================] - 0s 34ms/step - loss: 0.0749 - accuracy: 0.9762 - val_loss: 0.1219 - val_accuracy: 0.9400
# Epoch 7/10
# 11/11 [==============================] - 0s 40ms/step - loss: 0.0566 - accuracy: 0.9852 - val_loss: 0.1086 - val_accuracy: 0.9533
# Epoch 8/10
# 11/11 [==============================] - 0s 33ms/step - loss: 0.0413 - accuracy: 0.9918 - val_loss: 0.0870 - val_accuracy: 0.9667
# Epoch 9/10
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0328 - accuracy: 0.9941 - val_loss: 0.0844 - val_accuracy: 0.9733
# Epoch 10/10
# 11/11 [==============================] - 0s 29ms/step - loss: 0.0287 - accuracy: 0.9970 - val_loss: 0.0700 - val_accuracy: 0.9733
# Epoch 1/10
# 11/11 [==============================] - 1s 33ms/step - loss: 0.6901 - accuracy: 0.7275 - val_loss: 0.2909 - val_accuracy: 0.8933
# Epoch 2/10
# 11/11 [==============================] - 0s 21ms/step - loss: 0.2337 - accuracy: 0.9094 - val_loss: 0.1160 - val_accuracy: 0.9600
# Epoch 3/10
# 11/11 [==============================] - 0s 22ms/step - loss: 0.1454 - accuracy: 0.9458 - val_loss: 0.1077 - val_accuracy: 0.9600
# Epoch 4/10
# 11/11 [==============================] - 0s 20ms/step - loss: 0.1115 - accuracy: 0.9666 - val_loss: 0.0779 - val_accuracy: 0.9800
# Epoch 5/10
# 11/11 [==============================] - 0s 19ms/step - loss: 0.0805 - accuracy: 0.9792 - val_loss: 0.0740 - val_accuracy: 0.9800
# Epoch 6/10
# 11/11 [==============================] - 0s 20ms/step - loss: 0.0648 - accuracy: 0.9866 - val_loss: 0.0681 - val_accuracy: 0.9800
# Epoch 7/10
# 11/11 [==============================] - 0s 20ms/step - loss: 0.0523 - accuracy: 0.9889 - val_loss: 0.0668 - val_accuracy: 0.9800
# Epoch 8/10
# 11/11 [==============================] - 0s 21ms/step - loss: 0.0438 - accuracy: 0.9926 - val_loss: 0.0669 - val_accuracy: 0.9800
# Epoch 9/10
# 11/11 [==============================] - 0s 19ms/step - loss: 0.0394 - accuracy: 0.9933 - val_loss: 0.0671 - val_accuracy: 0.9733
# Epoch 10/10
# 11/11 [==============================] - 0s 23ms/step - loss: 0.0323 - accuracy: 0.9926 - val_loss: 0.0658 - val_accuracy: 0.9800
# Epoch 1/10
# 11/11 [==============================] - 1s 33ms/step - loss: 0.5589 - accuracy: 0.7713 - val_loss: 0.2262 - val_accuracy: 0.8800
# Epoch 2/10
# 11/11 [==============================] - 0s 21ms/step - loss: 0.1800 - accuracy: 0.9280 - val_loss: 0.1596 - val_accuracy: 0.9400
# Epoch 3/10
# 11/11 [==============================] - 0s 21ms/step - loss: 0.1086 - accuracy: 0.9599 - val_loss: 0.1406 - val_accuracy: 0.9533
# Epoch 4/10
# 11/11 [==============================] - 0s 19ms/step - loss: 0.0764 - accuracy: 0.9710 - val_loss: 0.1356 - val_accuracy: 0.9533
# Epoch 5/10
# 11/11 [==============================] - 0s 18ms/step - loss: 0.0494 - accuracy: 0.9903 - val_loss: 0.1319 - val_accuracy: 0.9667
# Epoch 6/10
# 11/11 [==============================] - 0s 21ms/step - loss: 0.0390 - accuracy: 0.9941 - val_loss: 0.1336 - val_accuracy: 0.9533
# Epoch 7/10
# 11/11 [==============================] - 0s 22ms/step - loss: 0.0337 - accuracy: 0.9955 - val_loss: 0.1262 - val_accuracy: 0.9600
# Epoch 8/10
# 11/11 [==============================] - 0s 20ms/step - loss: 0.0281 - accuracy: 0.9963 - val_loss: 0.1317 - val_accuracy: 0.9533
# Epoch 9/10
# 11/11 [==============================] - 0s 19ms/step - loss: 0.0218 - accuracy: 0.9993 - val_loss: 0.1335 - val_accuracy: 0.9600
# Epoch 10/10
# 11/11 [==============================] - 0s 18ms/step - loss: 0.0174 - accuracy: 0.9985 - val_loss: 0.1345 - val_accuracy: 0.9533
# Epoch 1/10
# 11/11 [==============================] - 1s 37ms/step - loss: 0.6305 - accuracy: 0.7157 - val_loss: 0.2780 - val_accuracy: 0.8800
# Epoch 2/10
# 11/11 [==============================] - 0s 23ms/step - loss: 0.2555 - accuracy: 0.8872 - val_loss: 0.1435 - val_accuracy: 0.9533
# Epoch 3/10
# 11/11 [==============================] - 0s 20ms/step - loss: 0.1453 - accuracy: 0.9458 - val_loss: 0.1293 - val_accuracy: 0.9600
# Epoch 4/10
# 11/11 [==============================] - 0s 20ms/step - loss: 0.1135 - accuracy: 0.9547 - val_loss: 0.1051 - val_accuracy: 0.9667
# Epoch 5/10
# 11/11 [==============================] - 0s 20ms/step - loss: 0.0751 - accuracy: 0.9785 - val_loss: 0.1045 - val_accuracy: 0.9600
# Epoch 6/10
# 11/11 [==============================] - 0s 20ms/step - loss: 0.0616 - accuracy: 0.9844 - val_loss: 0.0991 - val_accuracy: 0.9733
# Epoch 7/10
# 11/11 [==============================] - 0s 21ms/step - loss: 0.0521 - accuracy: 0.9889 - val_loss: 0.0924 - val_accuracy: 0.9667
# Epoch 8/10
# 11/11 [==============================] - 0s 22ms/step - loss: 0.0401 - accuracy: 0.9948 - val_loss: 0.0893 - val_accuracy: 0.9667
# Epoch 9/10
# 11/11 [==============================] - 0s 20ms/step - loss: 0.0337 - accuracy: 0.9948 - val_loss: 0.0882 - val_accuracy: 0.9600
# Epoch 10/10
# 11/11 [==============================] - 0s 18ms/step - loss: 0.0306 - accuracy: 0.9941 - val_loss: 0.0882 - val_accuracy: 0.9667
# Epoch 1/10
# 11/11 [==============================] - 1s 38ms/step - loss: 0.6551 - accuracy: 0.7120 - val_loss: 0.2580 - val_accuracy: 0.9000
# Epoch 2/10
# 11/11 [==============================] - 0s 31ms/step - loss: 0.1919 - accuracy: 0.9317 - val_loss: 0.2019 - val_accuracy: 0.9133
# Epoch 3/10
# 11/11 [==============================] - 0s 26ms/step - loss: 0.1272 - accuracy: 0.9480 - val_loss: 0.1520 - val_accuracy: 0.9400
# Epoch 4/10
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0806 - accuracy: 0.9666 - val_loss: 0.1178 - val_accuracy: 0.9467
# Epoch 5/10
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0531 - accuracy: 0.9866 - val_loss: 0.1158 - val_accuracy: 0.9533
# Epoch 6/10
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0429 - accuracy: 0.9889 - val_loss: 0.1089 - val_accuracy: 0.9533
# Epoch 7/10
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0368 - accuracy: 0.9933 - val_loss: 0.0916 - val_accuracy: 0.9600
# Epoch 8/10
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0314 - accuracy: 0.9955 - val_loss: 0.0894 - val_accuracy: 0.9600
# Epoch 9/10
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0214 - accuracy: 0.9985 - val_loss: 0.0907 - val_accuracy: 0.9667
# Epoch 10/10
# 11/11 [==============================] - 0s 25ms/step - loss: 0.0178 - accuracy: 0.9993 - val_loss: 0.0861 - val_accuracy: 0.9733
# Epoch 1/10
# 11/11 [==============================] - 1s 38ms/step - loss: 1.0703 - accuracy: 0.6206 - val_loss: 0.4085 - val_accuracy: 0.7800
# Epoch 2/10
# 11/11 [==============================] - 0s 30ms/step - loss: 0.3394 - accuracy: 0.8293 - val_loss: 0.3286 - val_accuracy: 0.8400
# Epoch 3/10
# 11/11 [==============================] - 0s 27ms/step - loss: 0.2227 - accuracy: 0.9079 - val_loss: 0.2436 - val_accuracy: 0.9067
# Epoch 4/10
# 11/11 [==============================] - 0s 28ms/step - loss: 0.1670 - accuracy: 0.9347 - val_loss: 0.2343 - val_accuracy: 0.9200
# Epoch 5/10
# 11/11 [==============================] - 0s 25ms/step - loss: 0.1329 - accuracy: 0.9540 - val_loss: 0.2058 - val_accuracy: 0.9267
# Epoch 6/10
# 11/11 [==============================] - 0s 26ms/step - loss: 0.1133 - accuracy: 0.9607 - val_loss: 0.1939 - val_accuracy: 0.9333
# Epoch 7/10
# 11/11 [==============================] - 0s 28ms/step - loss: 0.0988 - accuracy: 0.9710 - val_loss: 0.1848 - val_accuracy: 0.9400
# Epoch 8/10
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0881 - accuracy: 0.9785 - val_loss: 0.1800 - val_accuracy: 0.9467
# Epoch 9/10
# 11/11 [==============================] - 0s 25ms/step - loss: 0.0817 - accuracy: 0.9814 - val_loss: 0.1730 - val_accuracy: 0.9467
# Epoch 10/10
# 11/11 [==============================] - 0s 24ms/step - loss: 0.0709 - accuracy: 0.9874 - val_loss: 0.1650 - val_accuracy: 0.9467
# Epoch 1/10
# 11/11 [==============================] - 2s 52ms/step - loss: 0.6969 - accuracy: 0.7283 - val_loss: 0.2562 - val_accuracy: 0.9067
# Epoch 2/10
# 11/11 [==============================] - 0s 30ms/step - loss: 0.1908 - accuracy: 0.9265 - val_loss: 0.2013 - val_accuracy: 0.9267
# Epoch 3/10
# 11/11 [==============================] - 0s 33ms/step - loss: 0.1176 - accuracy: 0.9592 - val_loss: 0.1705 - val_accuracy: 0.9133
# Epoch 4/10
# 11/11 [==============================] - 0s 31ms/step - loss: 0.0744 - accuracy: 0.9777 - val_loss: 0.1368 - val_accuracy: 0.9467
# Epoch 5/10
# 11/11 [==============================] - 0s 34ms/step - loss: 0.0531 - accuracy: 0.9866 - val_loss: 0.1366 - val_accuracy: 0.9400
# Epoch 6/10
# 11/11 [==============================] - 0s 28ms/step - loss: 0.0377 - accuracy: 0.9941 - val_loss: 0.1284 - val_accuracy: 0.9467
# Epoch 7/10
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0280 - accuracy: 0.9955 - val_loss: 0.1367 - val_accuracy: 0.9533
# Epoch 8/10
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0233 - accuracy: 0.9970 - val_loss: 0.1284 - val_accuracy: 0.9533
# Epoch 9/10
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0201 - accuracy: 0.9985 - val_loss: 0.1221 - val_accuracy: 0.9600
# Epoch 10/10
# 11/11 [==============================] - 0s 30ms/step - loss: 0.0174 - accuracy: 0.9993 - val_loss: 0.1312 - val_accuracy: 0.9533
# Epoch 1/10
# 11/11 [==============================] - 1s 39ms/step - loss: 0.6906 - accuracy: 0.6978 - val_loss: 0.3168 - val_accuracy: 0.8800
# Epoch 2/10
# 11/11 [==============================] - 0s 31ms/step - loss: 0.2258 - accuracy: 0.9191 - val_loss: 0.2190 - val_accuracy: 0.9133
# Epoch 3/10
# 11/11 [==============================] - 0s 35ms/step - loss: 0.1513 - accuracy: 0.9480 - val_loss: 0.1676 - val_accuracy: 0.9400
# Epoch 4/10
# 11/11 [==============================] - 0s 35ms/step - loss: 0.1132 - accuracy: 0.9629 - val_loss: 0.1515 - val_accuracy: 0.9600
# Epoch 5/10
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0891 - accuracy: 0.9770 - val_loss: 0.1400 - val_accuracy: 0.9600
# Epoch 6/10
# 11/11 [==============================] - 0s 25ms/step - loss: 0.0721 - accuracy: 0.9822 - val_loss: 0.1451 - val_accuracy: 0.9600
# Epoch 7/10
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0687 - accuracy: 0.9859 - val_loss: 0.1548 - val_accuracy: 0.9533
# Epoch 8/10
# 11/11 [==============================] - 0s 21ms/step - loss: 0.0663 - accuracy: 0.9852 - val_loss: 0.1458 - val_accuracy: 0.9533
# Epoch 9/10
# 11/11 [==============================] - 0s 33ms/step - loss: 0.0544 - accuracy: 0.9881 - val_loss: 0.1337 - val_accuracy: 0.9600
# Epoch 10/10
# 11/11 [==============================] - 0s 22ms/step - loss: 0.0411 - accuracy: 0.9911 - val_loss: 0.1146 - val_accuracy: 0.9667
# Epoch 1/10
# 11/11 [==============================] - 1s 32ms/step - loss: 0.6813 - accuracy: 0.7327 - val_loss: 0.2253 - val_accuracy: 0.9000
# Epoch 2/10
# 11/11 [==============================] - 0s 26ms/step - loss: 0.1900 - accuracy: 0.9287 - val_loss: 0.1641 - val_accuracy: 0.9400
# Epoch 3/10
# 11/11 [==============================] - 0s 22ms/step - loss: 0.1327 - accuracy: 0.9495 - val_loss: 0.1496 - val_accuracy: 0.9400
# Epoch 4/10
# 11/11 [==============================] - 0s 22ms/step - loss: 0.0950 - accuracy: 0.9636 - val_loss: 0.1582 - val_accuracy: 0.9333
# Epoch 5/10
# 11/11 [==============================] - 0s 24ms/step - loss: 0.0680 - accuracy: 0.9829 - val_loss: 0.1469 - val_accuracy: 0.9533
# Epoch 6/10
# 11/11 [==============================] - 0s 21ms/step - loss: 0.0543 - accuracy: 0.9896 - val_loss: 0.1454 - val_accuracy: 0.9400
# Epoch 7/10
# 11/11 [==============================] - 0s 20ms/step - loss: 0.0450 - accuracy: 0.9881 - val_loss: 0.1474 - val_accuracy: 0.9333
# Epoch 8/10
# 11/11 [==============================] - 0s 23ms/step - loss: 0.0368 - accuracy: 0.9963 - val_loss: 0.1654 - val_accuracy: 0.9400
# Epoch 9/10
# 11/11 [==============================] - 0s 24ms/step - loss: 0.0306 - accuracy: 0.9970 - val_loss: 0.1544 - val_accuracy: 0.9267
# Epoch 10/10
# 11/11 [==============================] - 0s 19ms/step - loss: 0.0245 - accuracy: 0.9993 - val_loss: 0.1548 - val_accuracy: 0.9333

# %% [markdown]
# We aggregate each model individual predictions to form a final prediction.

# %%
predictions = []
for i in range(n_estimators):
    predictions.append(models[i].predict(test_features))
    
predictions = np.array(predictions)
predictions = predictions.sum(axis = 0)
pred_labels = predictions.argmax(axis=1)
# Out:
# 20/20 [==============================] - 0s 3ms/step
# 20/20 [==============================] - 0s 3ms/step
# 20/20 [==============================] - 0s 3ms/step
# 20/20 [==============================] - 0s 4ms/step
# 20/20 [==============================] - 0s 4ms/step
# 20/20 [==============================] - 0s 4ms/step
# 20/20 [==============================] - 0s 3ms/step
# 20/20 [==============================] - 0s 3ms/step
# 20/20 [==============================] - 0s 3ms/step
# 20/20 [==============================] - 0s 4ms/step

# %% [markdown]
# We should improve our result as we have a lower variance.

# %%
from sklearn.metrics import accuracy_score
print("Accuracy : {}".format(accuracy_score(test_labels, pred_labels)))
# Out:
# Accuracy : 0.9467741935483871

# %% [markdown]
# # Fine Tuning VGG ImageNet

# %%
from keras.models import Model

model = VGG16(weights='imagenet', include_top=False)
model = Model(inputs=model.inputs, outputs=model.layers[-5].output)

# %%
train_features = model.predict(train_images)
test_features = model.predict(test_images)
# Out:
# 59/59 [==============================] - 56s 947ms/step
# 20/20 [==============================] - 18s 908ms/step

# %%
from keras.layers import Input, Dense, Conv2D, Activation , MaxPooling2D, Flatten

model2 = VGG16(weights='imagenet', include_top=False)

input_shape = model2.layers[-4].get_input_shape_at(0) # get the input shape of desired layer
layer_input = Input(shape = (9, 9, 512)) # a new input tensor to be able to feed the desired layer
# https://stackoverflow.com/questions/52800025/keras-give-input-to-intermediate-layer-and-get-final-output

x = layer_input
for layer in model2.layers[-4::1]:
    x = layer(x)
    
x = Conv2D(48, (3, 3), activation='relu')(x)
x = MaxPooling2D(pool_size=(2, 2))(x)
x = Flatten()(x)
x = Dense(100,activation='relu')(x)
x = Dense(3,activation='softmax')(x)

# create the model
new_model = Model(layer_input, x)

# %%
new_model.compile(optimizer = 'adam', loss = 'sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
new_model.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_6 (InputLayer)        [(None, 9, 9, 512)]       0
#
#  block5_conv1 (Conv2D)       multiple                  2359808
#
#  block5_conv2 (Conv2D)       multiple                  2359808
#
#  block5_conv3 (Conv2D)       multiple                  2359808
#
#  block5_pool (MaxPooling2D)  multiple                  0
#
#  conv2d_3 (Conv2D)           (None, 2, 2, 48)          221232
#
#  max_pooling2d_3 (MaxPoolin  (None, 1, 1, 48)          0
#  g2D)
#
#  flatten_13 (Flatten)        (None, 48)                0
#
#  dense_26 (Dense)            (None, 100)               4900
#
#  dense_27 (Dense)            (None, 3)                 303
#
# =================================================================
# Total params: 7305859 (27.87 MB)
# Trainable params: 7305859 (27.87 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
history = new_model.fit(train_features, train_labels, batch_size=56, epochs=10, validation_split = 0.2)
# Out:
# Epoch 1/10
# 27/27 [==============================] - 25s 873ms/step - loss: 0.7061 - accuracy: 0.6399 - val_loss: 0.2432 - val_accuracy: 0.9040
# Epoch 2/10
# 27/27 [==============================] - 23s 856ms/step - loss: 0.2214 - accuracy: 0.9218 - val_loss: 0.2395 - val_accuracy: 0.9200
# Epoch 3/10
# 27/27 [==============================] - 23s 870ms/step - loss: 0.1258 - accuracy: 0.9546 - val_loss: 0.1923 - val_accuracy: 0.9413
# Epoch 4/10
# 27/27 [==============================] - 24s 889ms/step - loss: 0.1005 - accuracy: 0.9606 - val_loss: 0.1825 - val_accuracy: 0.9387
# Epoch 5/10
# 27/27 [==============================] - 23s 866ms/step - loss: 0.0743 - accuracy: 0.9719 - val_loss: 0.1456 - val_accuracy: 0.9600
# Epoch 6/10
# 27/27 [==============================] - 25s 929ms/step - loss: 0.0339 - accuracy: 0.9900 - val_loss: 0.3479 - val_accuracy: 0.9280
# Epoch 7/10
# 27/27 [==============================] - 26s 953ms/step - loss: 0.0685 - accuracy: 0.9753 - val_loss: 0.1641 - val_accuracy: 0.9467
# Epoch 8/10
# 27/27 [==============================] - 29s 1s/step - loss: 0.0232 - accuracy: 0.9920 - val_loss: 0.3803 - val_accuracy: 0.9120
# Epoch 9/10
# 27/27 [==============================] - 30s 1s/step - loss: 0.0089 - accuracy: 0.9960 - val_loss: 0.1995 - val_accuracy: 0.9387
# Epoch 10/10
# 27/27 [==============================] - 24s 884ms/step - loss: 0.0078 - accuracy: 0.9973 - val_loss: 0.3233 - val_accuracy: 0.9387

# %%
# Save the model to a file
model.save('model_intelimage.h5')
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# c:\Users\MARLINA\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
plot_accuracy_loss(history)

# Specify the directory and filename for saving the plot
save_dir = '/SEMESTER5/TUGASKEMAL'  # Change to your desired directory
save_filename = 'train_test_plot_intelimage.png'  # Change to your desired filename

# Save the plot to the specified directory and filename
plt.savefig(os.path.join(save_dir, save_filename))

# %%
from sklearn.metrics import accuracy_score

predictions = new_model.predict(test_features)    
pred_labels = np.argmax(predictions, axis = 1)
print("Accuracy : {}".format(accuracy_score(test_labels, pred_labels)))
# Out:
# 20/20 [==============================] - 3s 146ms/step
# Accuracy : 0.9483870967741935
